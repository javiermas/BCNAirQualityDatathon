# %%
# %load_ext autoreload
# %autoreload 2
import sys
import pandas as pd
from airquality.data.prepare_data import create_model_matrix
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('~/Cloud/BCNAirQualityDatathon/data/raw/AirQualityUCI.csv', sep=';').iloc[:,:-2].dropna()

# %%
data.tail()
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21,9  29,3  0,7568
# 9353       1269.0  24,3  23,7  0,7119
# 9354       1092.0  26,9  18,3  0,6406
# ...

# %%
data_proc = create_model_matrix(data.drop('T', axis=1), data['T'], 2)

# %%
data_proc.columns
# Out:
# Index([u'Date_lag_0', u'Time_lag_0', u'CO(GT)_lag_0', u'PT08.S1(CO)_lag_0',
#        u'NMHC(GT)_lag_0', u'C6H6(GT)_lag_0', u'PT08.S2(NMHC)_lag_0',
#        u'NOx(GT)_lag_0', u'PT08.S3(NOx)_lag_0', u'NO2(GT)_lag_0',
#        u'PT08.S4(NO2)_lag_0', u'PT08.S5(O3)_lag_0', u'T_lag_0', u'RH_lag_0',
#        u'AH_lag_0', u'Date_lag_0_lag_1', u'Time_lag_0_lag_1',
#        u'CO(GT)_lag_0_lag_1', u'PT08.S1(CO)_lag_0_lag_1',
#        u'NMHC(GT)_lag_0_lag_1', u'C6H6(GT)_lag_0_lag_1',
#        u'PT08.S2(NMHC)_lag_0_lag_1', u'NOx(GT)_lag_0_lag_1',
#        u'PT08.S3(NOx)_lag_0_lag_1', u'NO2(GT)_lag_0_lag_1',
#        u'PT08.S4(NO2)_lag_0_lag_1', u'PT08.S5(O3)_lag_0_lag_1',
#        u'T_lag_0_lag_1', u'RH_lag_0_lag_1', u'AH_lag_0_lag_1',
#        u'Date_lag_0_lag_2', u'Time_lag_0_lag_2', u'CO(GT)_lag_0_lag_2',
#        u'PT08.S1(CO)_lag_0_lag_2', u'NMHC(GT)_lag_0_lag_2',
#        u'C6H6(GT)_lag_0_lag_2', u'PT08.S2(NMHC)_lag_0_lag_2',
#        u'NOx(GT)_lag_0_lag_2', u'PT08.S3(NOx)_lag_0_lag_2',
# ...

# %%
data_proc
# Out:
#       Date_lag_0 Time_lag_0 CO(GT)_lag_0  PT08.S1(CO)_lag_0  NMHC(GT)_lag_0  \
# 0            NaN        NaN          NaN                NaN             NaN
# 1            NaN        NaN          NaN                NaN             NaN
# 2     10/03/2004   20.00.00          2,2             1402.0            88.0
# 3     10/03/2004   21.00.00          2,2             1376.0            80.0
# 4     10/03/2004   22.00.00          1,6             1272.0            51.0
# 5     10/03/2004   23.00.00          1,2             1197.0            38.0
# 6     11/03/2004   00.00.00          1,2             1185.0            31.0
# 7     11/03/2004   01.00.00            1             1136.0            31.0
# 8     11/03/2004   02.00.00          0,9             1094.0            24.0
# 9     11/03/2004   03.00.00          0,6             1010.0            19.0
# 10    11/03/2004   04.00.00         -200             1011.0            14.0
# ...

# %%
pd.DataFrame.from_csv('data/raw/AirQualityUCI.csv')
# Out:
# /Users/b.yc0006/jonassucks/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-046aee05a753> in <module>()
# ----> 1 pd.DataFrame.from_csv('data/raw/AirQualityUCI.csv')
#
# /Users/b.yc0006/jonassucks/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1359                           parse_dates=parse_dates, index_col=index_col,
#    1360                           encoding=encoding, tupleize_cols=tupleize_cols,
# ...

# %%
data_proc
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 2     10/03/2004  20.00.00     2,2       1402.0      88.0       9,0
# 3     10/03/2004  21.00.00     2,2       1376.0      80.0       9,2
# 4     10/03/2004  22.00.00     1,6       1272.0      51.0       6,5
# 5     10/03/2004  23.00.00     1,2       1197.0      38.0       4,7
# 6     11/03/2004  00.00.00     1,2       1185.0      31.0       3,6
# 7     11/03/2004  01.00.00       1       1136.0      31.0       3,3
# 8     11/03/2004  02.00.00     0,9       1094.0      24.0       2,3
# 9     11/03/2004  03.00.00     0,6       1010.0      19.0       1,7
# 10    11/03/2004  04.00.00    -200       1011.0      14.0       1,3
# 11    11/03/2004  05.00.00     0,7       1066.0       8.0       1,1
# 12    11/03/2004  06.00.00     0,7       1052.0      16.0       1,6
# 13    11/03/2004  07.00.00     1,1       1144.0      29.0       3,2
# 14    11/03/2004  08.00.00       2       1333.0      64.0       8,0
# ...
